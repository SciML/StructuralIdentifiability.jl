# %%
include("io_equation.jl")
# Out:
# $\require{action}$
#  -----    -----    -----      -      -----
# |     |  |     |  |     |    | |    |     |
# |     |  |        |         |   |   |     |
# |     |   -----   |        |     |  |-----
# |     |        |  |        |-----|  |   |
# |     |  |     |  |     |  |     |  |    |
#  -----    -----    -----   -     -  -     -
#
# ...combining (and extending) GAP, Hecke, Nemo, Polymake and Singular
# Version 0.3.0 ...
#  ... which comes with absolutely no warranty whatsoever
# Type: '?Oscar' for more information
# (c) 2019-2020 by The Oscar Development Team
# find_ioequation (generic function with 2 methods)

# %%
# SIWR Cholera model
logger = Logging.SimpleLogger(stdout, Logging.Debug)
global_logger(logger)

ode = @ODEmodel(
    S'(t) = mu - bi * S(t) * I(t) - bw * S(t) * W(t) - mu * S(t) + a * R(t),
    I'(t) = bw * S(t) * W(t) + bi * S(t) * I(t) - (gam + mu) * I(t),
    W'(t) = xi * (I(t) - W(t)),
    R'(t) = gam * I(t) - (mu + a) * R(t),
    [k]
)

@time io_equation = find_ioequation(ode, [k * I]);
# Out:
# Summary of the model:
# State variables: I, R, W, S
# Parameter: a, mu, bi, bw, gam, xi
# Inputs:
# ┌ Debug: Current degrees of io-equations [(1, [1])]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:107
# ┌ Debug: Orders: [0]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:108
# ┌ Debug: Sizes: [2]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:109
# ┌ Debug: Scores: Tuple{Int64,Rational{Int64},Int64,Int64}[(1, -14//15, 2, 1)]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:120
# ┌ Debug: Prolonging output number 1
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:123
# ┌ Debug: Prolonging
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:127
# ┌ Debug: Eliminating the derivative of W
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:131
# ┌ Debug: Generating new point on the variety
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:196
# ┌ Debug: Preparing initial condition
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:200
# ┌ Debug: Computing a power series solution
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:206
# ┌ Debug: Evaluating outputs
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:216
# ┌ Debug: Constructing the point
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:227
# ┌ Debug: Eliminating the derivative of S
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:131
# ┌ Debug: Eliminating the derivative of I
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:131
# ┌ Debug: 	 Decreasing degree with linear combination 2020-09-22T19:45:52.715
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:297
# ┌ Debug: Eliminating the derivative of R
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:131
# ┌ Debug: Elimination of I, 3 left; 2020-09-22T19:45:52.731
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:141
# ┌ Debug: Elimination in states
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:204
# ┌ Debug: 	 Elimination in the equation for W
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:207
# ┌ Debug: Calculating Sylvester matrix
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:349
# ┌ Debug: Simplifying the matrix 2020-09-22T19:45:52.731
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:353
# ┌ Debug: Removed factors Int64[]
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:356
# ┌ Debug: 	 Matrix size:
# │  [1  1]
# │ [2  1]
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:363
# ┌ Debug: 	 Computing determinant 2020-09-22T19:45:53.001
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:364
# ┌ Debug: Discarded: ((1,), (1,)); 2020-09-22T19:45:53.499
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((1,), (2,)); 2020-09-22T19:45:53.541
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((), ()); 2020-09-22T19:45:53.541
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: 	 Elimination in the equation for S
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:207
# ┌ Debug: Calculating Sylvester matrix
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:349
# ┌ Debug: Simplifying the matrix 2020-09-22T19:45:53.559
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:353
# ┌ Debug: Removed factors Int64[]
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:356
# ┌ Debug: 	 Matrix size:
# │  [1  1]
# │ [5  1]
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:363
# ┌ Debug: 	 Computing determinant 2020-09-22T19:45:53.559
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:364
# ┌ Debug: Discarded: ((1,), (1,)); 2020-09-22T19:45:53.559
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((1,), (2,)); 2020-09-22T19:45:53.559
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((), ()); 2020-09-22T19:45:53.56
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: 	 Elimination in the equation for R
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:207
# ┌ Debug: Calculating Sylvester matrix
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:349
# ┌ Debug: Simplifying the matrix 2020-09-22T19:45:53.56
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:353
# ┌ Debug: Removed factors Int64[]
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:356
# ┌ Debug: 	 Matrix size:
# │  [1  1]
# │ [3  1]
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:363
# ┌ Debug: 	 Computing determinant 2020-09-22T19:45:53.56
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:364
# ┌ Debug: Discarded: ((1,), (1,)); 2020-09-22T19:45:53.56
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((1,), (2,)); 2020-09-22T19:45:53.56
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((), ()); 2020-09-22T19:45:53.561
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Elimination in y_equations
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:211
# ┌ Debug: 	 Elimination in the prolonged equation
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:220
# ┌ Debug: 	 Decreasing degree with linear combination 2020-09-22T19:45:53.561
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:297
# ┌ Debug: Current degrees of io-equations [(1, [1, 1])]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:107
# ┌ Debug: Orders: [1]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:108
# ┌ Debug: Sizes: [5]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:109
# ┌ Debug: Scores: Tuple{Int64,Rational{Int64},Int64,Int64}[(1, -11//6, 5, 1)]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:120
# ┌ Debug: Prolonging output number 1
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:123
# ┌ Debug: Prolonging
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:127
# ┌ Debug: Eliminating the derivative of W
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:131
# ┌ Debug: 	 Decreasing degree with linear combination 2020-09-22T19:45:53.567
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:297
# ┌ Debug: Eliminating the derivative of S
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:131
# ┌ Debug: Calculating Sylvester matrix
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:349
# ┌ Debug: Simplifying the matrix 2020-09-22T19:45:53.567
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:353
# ┌ Debug: Removed factors Int64[]
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:356
# ┌ Debug: 	 Matrix size:
# │  [6  2]
# │ [5  1]
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:363
# ┌ Debug: 	 Computing determinant 2020-09-22T19:45:53.568
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:364
# ┌ Debug: Discarded: ((1,), (1,)); 2020-09-22T19:45:53.568
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((1,), (2,)); 2020-09-22T19:45:53.568
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((), ()); 2020-09-22T19:45:53.568
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Eliminating the derivative of R
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:131
# ┌ Debug: Elimination of S, 2 left; 2020-09-22T19:45:53.569
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:141
# ┌ Debug: 	 Applying variable change: W --> W - ( -bi*y1_0 )/( -bw*k ); 2020-09-22T19:45:53.569
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:153
# ┌ Debug: Change in the system
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:167
# ┌ Debug: Substitution in a polynomial of degree 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:49
# ┌ Debug: 	 Degree 0
# └ @ Main /home/gleb/code/EliminationODE/util.jl:52
# ┌ Debug: 	 Intermediate result of size 2
# └ @ Main /home/gleb/code/EliminationODE/util.jl:55
# ┌ Debug: 	 Degree 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:52
# ┌ Debug: 	 Intermediate result of size 4
# └ @ Main /home/gleb/code/EliminationODE/util.jl:55
# ┌ Debug: 	 Change in the equation for W
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:171
# ┌ Debug: Substitution in a polynomial of degree 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:49
# ┌ Debug: 	 Degree 0
# └ @ Main /home/gleb/code/EliminationODE/util.jl:52
# ┌ Debug: 	 Intermediate result of size 3
# └ @ Main /home/gleb/code/EliminationODE/util.jl:55
# ┌ Debug: 	 Degree 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:52
# ┌ Debug: 	 Intermediate result of size 5
# └ @ Main /home/gleb/code/EliminationODE/util.jl:55
# ┌ Debug: 	 Change in the equation for S
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:171
# ┌ Debug: Substitution in a polynomial of degree 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:49
# ┌ Debug: 	 Degree 0
# └ @ Main /home/gleb/code/EliminationODE/util.jl:52
# ┌ Debug: 	 Intermediate result of size 5
# └ @ Main /home/gleb/code/EliminationODE/util.jl:55
# ┌ Debug: 	 Degree 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:52
# ┌ Debug: 	 Intermediate result of size 5
# └ @ Main /home/gleb/code/EliminationODE/util.jl:55
# ┌ Debug: 	 Change in the equation for R
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:171
# ┌ Debug: Substitution in a polynomial of degree 0
# └ @ Main /home/gleb/code/EliminationODE/util.jl:49
# ┌ Debug: 	 Degree 0
# └ @ Main /home/gleb/code/EliminationODE/util.jl:52
# ┌ Debug: 	 Intermediate result of size 4
# └ @ Main /home/gleb/code/EliminationODE/util.jl:55
# ┌ Debug: Change in the outputs
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:175
# ┌ Debug: 	 Change in the 1 th output
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:178
# ┌ Debug: Substitution in a polynomial of degree 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:49
# ┌ Debug: 	 Degree 0
# └ @ Main /home/gleb/code/EliminationODE/util.jl:52
# ┌ Debug: 	 Intermediate result of size 4
# └ @ Main /home/gleb/code/EliminationODE/util.jl:55
# ┌ Debug: 	 Degree 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:52
# ┌ Debug: 	 Intermediate result of size 4
# └ @ Main /home/gleb/code/EliminationODE/util.jl:55
# ┌ Debug: 	 Change in the prolonged equation
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:182
# ┌ Debug: Substitution in a polynomial of degree 2
# └ @ Main /home/gleb/code/EliminationODE/util.jl:49
# ┌ Debug: 	 Degree 0
# └ @ Main /home/gleb/code/EliminationODE/util.jl:52
# ┌ Debug: 	 Intermediate result of size 9
# └ @ Main /home/gleb/code/EliminationODE/util.jl:55
# ┌ Debug: 	 Degree 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:52
# ┌ Debug: 	 Intermediate result of size 12
# └ @ Main /home/gleb/code/EliminationODE/util.jl:55
# ┌ Debug: 	 Degree 2
# └ @ Main /home/gleb/code/EliminationODE/util.jl:52
# ┌ Debug: 	 Intermediate result of size 11
# └ @ Main /home/gleb/code/EliminationODE/util.jl:55
# ┌ Debug: Unmixing the derivatives
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:186
# ┌ Debug: 	 Unmixing S
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:189
# ┌ Debug: 	 Factoring with Singular a polynomial of size 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:150
# ┌ Debug: Generating new point on the variety
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:196
# ┌ Debug: Preparing initial condition
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:200
# ┌ Debug: Computing a power series solution
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:206
# ┌ Debug: Evaluating outputs
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:216
# ┌ Debug: Constructing the point
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:227
# ┌ Debug: 	 	 Size of extra factor: 1; 2020-09-22T19:45:55.092
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:380
# ┌ Debug: 	 	 It is bw
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:381
# ┌ Debug: 	 	 Size of extra factor: 1; 2020-09-22T19:45:55.095
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:380
# ┌ Debug: 	 	 It is k
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:381
# ┌ Debug: 	 Unmixing R
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:189
# ┌ Debug: Change of variables performed
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:193
# ┌ Debug: Elimination in states
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:204
# ┌ Debug: 	 Elimination in the equation for W
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:207
# ┌ Debug: 	 Elimination in the equation for R
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:207
# ┌ Debug: Elimination in y_equations
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:211
# ┌ Debug: 	 Elimination in the prolonged equation
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:220
# ┌ Debug: Calculating Sylvester matrix
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:349
# ┌ Debug: Simplifying the matrix 2020-09-22T19:45:55.097
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:353
# ┌ Debug: Removed factors [1, 1]
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:356
# ┌ Debug: 	 Matrix size:
# │  [5  6]
# │ [3  1]
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:363
# ┌ Debug: 	 Computing determinant 2020-09-22T19:45:55.098
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:364
# ┌ Debug: Discarded: ((1,), (1,)); 2020-09-22T19:45:55.098
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((1,), (2,)); 2020-09-22T19:45:55.098
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((), ()); 2020-09-22T19:45:55.098
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: 	 Factoring with Singular a polynomial of size 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:150
# ┌ Debug: 	 Factoring with Singular a polynomial of size 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:150
# ┌ Debug: 	 	 Size of extra factor: 1; 2020-09-22T19:45:55.124
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:380
# ┌ Debug: 	 	 It is bw
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:381
# ┌ Debug: 	 	 Size of extra factor: 1; 2020-09-22T19:45:55.124
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:380
# ┌ Debug: 	 	 It is k
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:381
# ┌ Debug: Current degrees of io-equations [(1, [2, 1])]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:107
# ┌ Debug: Orders: [2]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:108
# ┌ Debug: Sizes: [22]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:109
# ┌ Debug: Scores: Tuple{Int64,Rational{Int64},Int64,Int64}[(1, -4//15, 22, 1)]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:120
# ┌ Debug: Prolonging output number 1
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:123
# ┌ Debug: Prolonging
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:127
# ┌ Debug: Eliminating the derivative of W
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:131
# ┌ Debug: 	 Decreasing degree with linear combination 2020-09-22T19:45:55.125
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:297
# ┌ Debug: Eliminating the derivative of R
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:131
# ┌ Debug: 	 Decreasing degree with linear combination 2020-09-22T19:45:55.126
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:297
# ┌ Debug: Elimination of R, 1 left; 2020-09-22T19:45:55.126
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:141
# ┌ Debug: Elimination in states
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:204
# ┌ Debug: 	 Elimination in the equation for W
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:207
# ┌ Debug: Elimination in y_equations
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:211
# ┌ Debug: 	 Elimination in the prolonged equation
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:220
# ┌ Debug: Calculating Sylvester matrix
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:349
# ┌ Debug: Simplifying the matrix 2020-09-22T19:45:55.127
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:353
# ┌ Debug: Removed factors [1]
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:356
# ┌ Debug: 	 Matrix size:
# │  [50  6]
# │ [21  1]
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:363
# ┌ Debug: 	 Computing determinant 2020-09-22T19:45:55.127
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:364
# ┌ Debug: Discarded: ((1,), (1,)); 2020-09-22T19:45:55.127
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((1,), (2,)); 2020-09-22T19:45:55.127
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((), ()); 2020-09-22T19:45:55.127
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: 	 	 Size of extra factor: 1; 2020-09-22T19:45:55.128
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:380
# ┌ Debug: 	 	 It is a
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:381
# ┌ Debug: 	 	 Size of extra factor: 1; 2020-09-22T19:45:55.128
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:380
# ┌ Debug: 	 	 It is bw
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:381
# ┌ Debug: 	 	 Size of extra factor: 1; 2020-09-22T19:45:55.128
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:380
# ┌ Debug: 	 	 It is W
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:381
# ┌ Debug: 	 	 Size of extra factor: 1; 2020-09-22T19:45:55.128
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:380
# ┌ Debug: 	 	 It is k
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:381
# ┌ Debug: Current degrees of io-equations [(1, [3])]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:107
# ┌ Debug: Orders: [3]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:108
# ┌ Debug: Sizes: [84]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:109
# ┌ Debug: Scores: Tuple{Int64,Rational{Int64},Int64,Int64}[(3, 9//5, 84, 1)]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:120
# ┌ Debug: Prolonging output number 1
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:123
# ┌ Debug: Prolonging
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:127
# ┌ Debug: Eliminating the derivative of W
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:131
# ┌ Debug: 	 Decreasing degree with linear combination 2020-09-22T19:45:55.129
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:297
# ┌ Debug: Elimination of W, 0 left; 2020-09-22T19:45:55.13
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:141
# ┌ Debug: Elimination in states
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:204
# ┌ Debug: Elimination in y_equations
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:211
# ┌ Debug: 	 Elimination in the prolonged equation
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:220
# ┌ Debug: Calculating Bezout Matrix 2020-09-22T19:45:55.13
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:345
# ┌ Debug: Simplifying the matrix 2020-09-22T19:45:55.133
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:353
# ┌ Debug: Removed factors [9, 1, 1, 3, 1, 1]
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:356
# ┌ Debug: 	 Matrix size:
# │  [ 23  179   83]
# │ [349  911  349]
# │ [173  349  321]
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:363
# ┌ Debug: 	 Computing determinant 2020-09-22T19:45:55.145
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:364
# ┌ Debug: Discarded: ((1, 2), (1, 2)); 2020-09-22T19:45:55.28
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((1, 2), (1, 3)); 2020-09-22T19:45:55.344
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((1,), (1,)); 2020-09-22T19:45:55.35
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((1, 2), (2, 3)); 2020-09-22T19:45:55.397
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((1,), (2,)); 2020-09-22T19:45:55.401
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((1,), (3,)); 2020-09-22T19:45:55.56
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((), ()); 2020-09-22T19:45:55.66
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: 	 Factoring with Singular a polynomial of size 9
# └ @ Main /home/gleb/code/EliminationODE/util.jl:150
# ┌ Debug: 	 Factoring with Singular a polynomial of size 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:150
# ┌ Debug: 	 Factoring with Singular a polynomial of size 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:150
# ┌ Debug: 	 Factoring with Singular a polynomial of size 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:150
# ┌ Debug: 	 Factoring with Singular a polynomial of size 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:150
# ┌ Debug: 	 	 Size of extra factor: 1; 2020-09-22T19:45:56.545
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:380
# ┌ Debug: 	 	 It is bw
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:381
# ┌ Debug: 	 	 Size of extra factor: 1; 2020-09-22T19:45:56.546
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:380
# ┌ Debug: 	 	 It is k
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:381
# ┌ Debug: 	 	 Size of extra factor: 3; 2020-09-22T19:45:56.546
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:380
# ┌ Debug: 	 	 It is mu*y1_0 + gam*y1_0 + y1_1
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:381
# ┌ Debug: 	 	 Size of extra factor: 3; 2020-09-22T19:45:56.546
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:380
# ┌ Debug: 	 	 It is bi*xi*y1_0 + bi*y1_1 + bw*xi*y1_0
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:381
#  16.512492 seconds (41.32 M allocations: 2.194 GiB, 4.91% gc time)

# %%
eq = io_equation[1]
length(eq)
# Out:
# 209349

# %%
y1_0, y1_1, y1_2, y1_3, y1_4 = gens(parent(eq))[end-4:end]
# Out:
# 5-element Array{fmpq_mpoly,1}:
#  y1_0
#  y1_1
#  y1_2
#  y1_3
#  y1_4

# %%
coef = extract_coefficients(eq, [y1_0, y1_1, y1_2, y1_3, y1_4])
sort(collect(values(coef)), by=length)[1:30]
# Out:
# 30-element Array{fmpq_mpoly,1}:
#  8*bi^4*k^2
#  12*bi^3*k^3
#  -108*bi^5*k
#  108*bi^4*k^2
#  8*bi^5*k
#  -3*bi^3*k^3
#  -108*bi^6
#  -9*bi^3*k^3
#  -104*bi^4*k^2
#  4*bi^3*k^3
#  9*bi^3*k^3
#  -108*bi^5*k
#  -54*bi^4*k^2
#  ⋮
#  18*bi^3*k^3
#  24*bi^4*k^2
#  27*bi^4*k^2
#  81*bi^4*k^2
#  -54*bi^4*k^2
#  -36*bi^4*k^2
#  -12*bi^3*xi*k^3 - 12*bi^2*bw*xi*k^3
#  12*a*mu*bi^3*k^4 + 12*mu^2*bi^3*k^4
#  2*a*mu*bi^3*k^4 + 2*mu^2*bi^3*k^4
#  -54*bi^4*xi*k^2 - 54*bi^3*bw*xi*k^2
#  -18*a*mu*bi^3*k^4 - 18*mu^2*bi^3*k^4
#  -648*bi^6*xi - 648*bi^5*bw*xi

# %%
@time check_identifiability(
    eq, 
    [a, bi, bw, gam, mu, xi, k]
)
# Out:
# ┌ Debug: Extracting coefficients
# └ @ Main /home/gleb/code/EliminationODE/util.jl:272
# ┌ Debug: Constructing equations
# └ @ Main /home/gleb/code/EliminationODE/util.jl:227
# ┌ Debug: Pivot polynomial is 81*bi^4*k^2
# └ @ Main /home/gleb/code/EliminationODE/util.jl:232
# ┌ Debug: Computing Groebner basis (772 equations)
# └ @ Main /home/gleb/code/EliminationODE/util.jl:244
# ┌ Debug: Producing the result
# └ @ Main /home/gleb/code/EliminationODE/util.jl:254
#   4.594051 seconds (19.82 M allocations: 997.211 MiB, 9.36% gc time)
# Dict{Any,Any} with 7 entries:
#   bw  => true
#   xi  => true
#   k   => true
#   mu  => true
#   a   => true
#   gam => true
#   bi  => true
