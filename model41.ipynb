# %%
include("io_equation.jl")
# Out:
# $\require{action}$
#  -----    -----    -----      -      -----
# |     |  |     |  |     |    | |    |     |
# |     |  |        |         |   |   |     |
# |     |   -----   |        |     |  |-----
# |     |        |  |        |-----|  |   |
# |     |  |     |  |     |  |     |  |    |
#  -----    -----    -----   -     -  -     -
#
# ...combining (and extending) GAP, Hecke, Nemo, Polymake and Singular
# Version 0.3.0 ...
#  ... which comes with absolutely no warranty whatsoever
# Type: '?Oscar' for more information
# (c) 2019-2020 by The Oscar Development Team
# find_ioequation (generic function with 2 methods)

# %%
 # model 41, normalized (all state variables are divided by N)
logger = Logging.SimpleLogger(stdout, Logging.Debug)
global_logger(logger)

ode = @ODEmodel(
    S'(t) = -b * S(t) * (I(t) + J(t) + q * A(t)),
    E'(t) = b * S(t) * (I(t) + J(t) + q * A(t)) - k * E(t),
    A'(t) = k * (1 - r) * E(t) - g1 * A(t),
    I'(t) = k * r * E(t) - (alpha + g1) * I(t),
    J'(t) = alpha * I(t) - g2 * J(t),
    C'(t) = alpha * I(t)
)

g = C

@time io_equations = find_ioequation(ode, [g]);
# Out:
# Summary of the model:
# State variables: I, A, J, S, E, C
# Parameter: b, alpha, g2, k, g1, q, r
# Inputs:
# ┌ Debug: Current degrees of io-equations [(1, [1])]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:107
# ┌ Debug: Orders: [0]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:108
# ┌ Debug: Sizes: [2]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:109
# ┌ Debug: Scores: Tuple{Int64,Rational{Int64},Int64,Int64}[(1, -14//15, 2, 1)]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:120
# ┌ Debug: Prolonging output number 1
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:123
# ┌ Debug: Prolonging
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:127
# ┌ Debug: Eliminating the derivative of E
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:131
# ┌ Debug: Generating new point on the variety
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:196
# ┌ Debug: Preparing initial condition
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:200
# ┌ Debug: Computing a power series solution
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:206
# ┌ Debug: Evaluating outputs
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:216
# ┌ Debug: Constructing the point
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:227
# ┌ Debug: Eliminating the derivative of I
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:131
# ┌ Debug: Eliminating the derivative of A
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:131
# ┌ Debug: Eliminating the derivative of C
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:131
# ┌ Debug: 	 Decreasing degree with linear combination 2020-09-22T20:01:40.884
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:297
# ┌ Debug: Eliminating the derivative of J
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:131
# ┌ Debug: Eliminating the derivative of S
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:131
# ┌ Debug: Elimination of C, 5 left; 2020-09-22T20:01:40.902
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:141
# ┌ Debug: Elimination in states
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:204
# ┌ Debug: 	 Elimination in the equation for E
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:207
# ┌ Debug: 	 Elimination in the equation for I
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:207
# ┌ Debug: 	 Elimination in the equation for A
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:207
# ┌ Debug: 	 Elimination in the equation for J
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:207
# ┌ Debug: 	 Elimination in the equation for S
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:207
# ┌ Debug: Elimination in y_equations
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:211
# ┌ Debug: 	 Elimination in the prolonged equation
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:220
# ┌ Debug: Current degrees of io-equations [(1, [1])]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:107
# ┌ Debug: Orders: [1]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:108
# ┌ Debug: Sizes: [2]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:109
# ┌ Debug: Scores: Tuple{Int64,Rational{Int64},Int64,Int64}[(1, -14//15, 2, 1)]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:120
# ┌ Debug: Prolonging output number 1
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:123
# ┌ Debug: Prolonging
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:127
# ┌ Debug: Eliminating the derivative of E
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:131
# ┌ Debug: Eliminating the derivative of I
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:131
# ┌ Debug: 	 Decreasing degree with linear combination 2020-09-22T20:01:40.91
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:297
# ┌ Debug: Eliminating the derivative of A
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:131
# ┌ Debug: Eliminating the derivative of J
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:131
# ┌ Debug: Eliminating the derivative of S
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:131
# ┌ Debug: Elimination of I, 4 left; 2020-09-22T20:01:40.91
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:141
# ┌ Debug: Elimination in states
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:204
# ┌ Debug: 	 Elimination in the equation for E
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:207
# ┌ Debug: Calculating Sylvester matrix
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:349
# ┌ Debug: Simplifying the matrix 2020-09-22T20:01:40.911
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:353
# ┌ Debug: Removed factors Int64[]
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:356
# ┌ Debug: 	 Matrix size:
# │  [1  1]
# │ [4  1]
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:363
# ┌ Debug: 	 Computing determinant 2020-09-22T20:01:41.207
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:364
# ┌ Debug: Discarded: ((1,), (1,)); 2020-09-22T20:01:41.699
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((1,), (2,)); 2020-09-22T20:01:41.747
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((), ()); 2020-09-22T20:01:41.747
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: 	 Elimination in the equation for A
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:207
# ┌ Debug: 	 Elimination in the equation for J
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:207
# ┌ Debug: 	 Decreasing degree with linear combination 2020-09-22T20:01:41.767
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:297
# ┌ Debug: 	 Elimination in the equation for S
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:207
# ┌ Debug: Calculating Sylvester matrix
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:349
# ┌ Debug: Simplifying the matrix 2020-09-22T20:01:41.768
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:353
# ┌ Debug: Removed factors Int64[]
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:356
# ┌ Debug: 	 Matrix size:
# │  [1  1]
# │ [3  1]
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:363
# ┌ Debug: 	 Computing determinant 2020-09-22T20:01:41.768
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:364
# ┌ Debug: Discarded: ((1,), (1,)); 2020-09-22T20:01:41.769
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((1,), (2,)); 2020-09-22T20:01:41.769
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((), ()); 2020-09-22T20:01:41.769
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Elimination in y_equations
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:211
# ┌ Debug: 	 Elimination in the prolonged equation
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:220
# ┌ Debug: 	 Decreasing degree with linear combination 2020-09-22T20:01:41.77
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:297
# ┌ Debug: Current degrees of io-equations [(1, [1])]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:107
# ┌ Debug: Orders: [2]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:108
# ┌ Debug: Sizes: [4]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:109
# ┌ Debug: Scores: Tuple{Int64,Rational{Int64},Int64,Int64}[(1, -13//15, 4, 1)]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:120
# ┌ Debug: Prolonging output number 1
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:123
# ┌ Debug: Prolonging
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:127
# ┌ Debug: Eliminating the derivative of E
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:131
# ┌ Debug: 	 Decreasing degree with linear combination 2020-09-22T20:01:41.771
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:297
# ┌ Debug: Eliminating the derivative of A
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:131
# ┌ Debug: Eliminating the derivative of J
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:131
# ┌ Debug: Eliminating the derivative of S
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:131
# ┌ Debug: Elimination of E, 3 left; 2020-09-22T20:01:41.772
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:141
# ┌ Debug: Elimination in states
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:204
# ┌ Debug: 	 Elimination in the equation for A
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:207
# ┌ Debug: Calculating Sylvester matrix
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:349
# ┌ Debug: Simplifying the matrix 2020-09-22T20:01:41.773
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:353
# ┌ Debug: Removed factors [1]
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:356
# ┌ Debug: 	 Matrix size:
# │  [3  1]
# │ [2  2]
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:363
# ┌ Debug: 	 Computing determinant 2020-09-22T20:01:41.773
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:364
# ┌ Debug: Discarded: ((1,), (1,)); 2020-09-22T20:01:41.773
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((1,), (2,)); 2020-09-22T20:01:41.774
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((), ()); 2020-09-22T20:01:41.774
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Generating new point on the variety
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:196
# ┌ Debug: Preparing initial condition
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:200
# ┌ Debug: Computing a power series solution
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:206
# ┌ Debug: Evaluating outputs
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:216
# ┌ Debug: Constructing the point
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:227
# ┌ Debug: 	 	 Size of extra factor: 1; 2020-09-22T20:01:41.87
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:380
# ┌ Debug: 	 	 It is k
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:381
# ┌ Debug: 	 Elimination in the equation for J
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:207
# ┌ Debug: 	 Elimination in the equation for S
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:207
# ┌ Debug: Elimination in y_equations
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:211
# ┌ Debug: 	 Elimination in the prolonged equation
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:220
# ┌ Debug: 	 Decreasing degree with linear combination 2020-09-22T20:01:41.873
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:297
# ┌ Debug: Current degrees of io-equations [(1, [1, 1, 1])]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:107
# ┌ Debug: Orders: [3]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:108
# ┌ Debug: Sizes: [9]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:109
# ┌ Debug: Scores: Tuple{Int64,Rational{Int64},Int64,Int64}[(1, -27//10, 9, 1)]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:120
# ┌ Debug: Prolonging output number 1
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:123
# ┌ Debug: Prolonging
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:127
# ┌ Debug: Eliminating the derivative of A
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:131
# ┌ Debug: 	 Decreasing degree with linear combination 2020-09-22T20:01:41.878
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:297
# ┌ Debug: Eliminating the derivative of J
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:131
# ┌ Debug: 	 Decreasing degree with linear combination 2020-09-22T20:01:41.879
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:297
# ┌ Debug: Eliminating the derivative of S
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:131
# ┌ Debug: Calculating Sylvester matrix
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:349
# ┌ Debug: Simplifying the matrix 2020-09-22T20:01:41.879
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:353
# ┌ Debug: Removed factors Int64[]
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:356
# ┌ Debug: 	 Matrix size:
# │  [16  3]
# │ [ 3  1]
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:363
# ┌ Debug: 	 Computing determinant 2020-09-22T20:01:41.879
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:364
# ┌ Debug: Discarded: ((1,), (1,)); 2020-09-22T20:01:41.88
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((1,), (2,)); 2020-09-22T20:01:41.88
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((), ()); 2020-09-22T20:01:41.88
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Elimination of S, 2 left; 2020-09-22T20:01:41.88
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:141
# ┌ Debug: 	 Applying variable change: A --> A - ( -alpha*J - y1_1 )/( -alpha*q ); 2020-09-22T20:01:41.881
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:153
# ┌ Debug: Change in the system
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:167
# ┌ Debug: Substitution in a polynomial of degree 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:49
# ┌ Debug: 	 Degree 0
# └ @ Main /home/gleb/code/EliminationODE/util.jl:52
# ┌ Debug: 	 Intermediate result of size 7
# └ @ Main /home/gleb/code/EliminationODE/util.jl:55
# ┌ Debug: 	 Degree 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:52
# ┌ Debug: 	 Intermediate result of size 10
# └ @ Main /home/gleb/code/EliminationODE/util.jl:55
# ┌ Debug: 	 Change in the equation for A
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:171
# ┌ Debug: Substitution in a polynomial of degree 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:49
# ┌ Debug: 	 Degree 0
# └ @ Main /home/gleb/code/EliminationODE/util.jl:52
# ┌ Debug: 	 Intermediate result of size 9
# └ @ Main /home/gleb/code/EliminationODE/util.jl:55
# ┌ Debug: 	 Degree 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:52
# ┌ Debug: 	 Intermediate result of size 12
# └ @ Main /home/gleb/code/EliminationODE/util.jl:55
# ┌ Debug: 	 Change in the equation for J
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:171
# ┌ Debug: Substitution in a polynomial of degree 0
# └ @ Main /home/gleb/code/EliminationODE/util.jl:49
# ┌ Debug: 	 Degree 0
# └ @ Main /home/gleb/code/EliminationODE/util.jl:52
# ┌ Debug: 	 Intermediate result of size 3
# └ @ Main /home/gleb/code/EliminationODE/util.jl:55
# ┌ Debug: 	 Change in the equation for S
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:171
# ┌ Debug: Substitution in a polynomial of degree 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:49
# ┌ Debug: 	 Degree 0
# └ @ Main /home/gleb/code/EliminationODE/util.jl:52
# ┌ Debug: 	 Intermediate result of size 3
# └ @ Main /home/gleb/code/EliminationODE/util.jl:55
# ┌ Debug: 	 Degree 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:52
# ┌ Debug: 	 Intermediate result of size 2
# └ @ Main /home/gleb/code/EliminationODE/util.jl:55
# ┌ Debug: Change in the outputs
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:175
# ┌ Debug: 	 Change in the 1 th output
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:178
# ┌ Debug: Substitution in a polynomial of degree 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:49
# ┌ Debug: 	 Degree 0
# └ @ Main /home/gleb/code/EliminationODE/util.jl:52
# ┌ Debug: 	 Intermediate result of size 8
# └ @ Main /home/gleb/code/EliminationODE/util.jl:55
# ┌ Debug: 	 Degree 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:52
# ┌ Debug: 	 Intermediate result of size 7
# └ @ Main /home/gleb/code/EliminationODE/util.jl:55
# ┌ Debug: 	 Change in the prolonged equation
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:182
# ┌ Debug: Substitution in a polynomial of degree 2
# └ @ Main /home/gleb/code/EliminationODE/util.jl:49
# ┌ Debug: 	 Degree 0
# └ @ Main /home/gleb/code/EliminationODE/util.jl:52
# ┌ Debug: 	 Intermediate result of size 18
# └ @ Main /home/gleb/code/EliminationODE/util.jl:55
# ┌ Debug: 	 Degree 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:52
# ┌ Debug: 	 Intermediate result of size 23
# └ @ Main /home/gleb/code/EliminationODE/util.jl:55
# ┌ Debug: 	 Degree 2
# └ @ Main /home/gleb/code/EliminationODE/util.jl:52
# ┌ Debug: 	 Intermediate result of size 19
# └ @ Main /home/gleb/code/EliminationODE/util.jl:55
# ┌ Debug: Unmixing the derivatives
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:186
# ┌ Debug: 	 Unmixing J
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:189
# ┌ Debug: 	 Decreasing degree with linear combination 2020-09-22T20:01:42.25
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:303
# ┌ Debug: 	 Factoring with Singular a polynomial of size 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:150
# ┌ Debug: 	 	 Size of extra factor: 1; 2020-09-22T20:01:43.422
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:380
# ┌ Debug: 	 	 It is q
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:381
# ┌ Debug: 	 	 Size of extra factor: 1; 2020-09-22T20:01:43.422
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:380
# ┌ Debug: 	 	 It is alpha
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:381
# ┌ Debug: 	 Unmixing S
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:189
# ┌ Debug: Change of variables performed
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:193
# ┌ Debug: Elimination in states
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:204
# ┌ Debug: 	 Elimination in the equation for A
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:207
# ┌ Debug: 	 Elimination in the equation for J
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:207
# ┌ Debug: Elimination in y_equations
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:211
# ┌ Debug: 	 Elimination in the prolonged equation
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:220
# ┌ Debug: Calculating Sylvester matrix
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:349
# ┌ Debug: Simplifying the matrix 2020-09-22T20:01:43.423
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:353
# ┌ Debug: Removed factors [1, 1, 1]
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:356
# ┌ Debug: 	 Matrix size:
# │  [6  13]
# │ [6   1]
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:363
# ┌ Debug: 	 Computing determinant 2020-09-22T20:01:43.424
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:364
# ┌ Debug: Discarded: ((1,), (1,)); 2020-09-22T20:01:43.424
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((1,), (2,)); 2020-09-22T20:01:43.424
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((), ()); 2020-09-22T20:01:43.424
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: 	 Factoring with Singular a polynomial of size 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:150
# ┌ Debug: 	 Factoring with Singular a polynomial of size 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:150
# ┌ Debug: 	 	 Size of extra factor: 1; 2020-09-22T20:01:43.44
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:380
# ┌ Debug: 	 	 It is alpha
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:381
# ┌ Debug: 	 	 Size of extra factor: 1; 2020-09-22T20:01:43.44
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:380
# ┌ Debug: 	 	 It is q
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:381
# ┌ Debug: 	 	 Size of extra factor: 1; 2020-09-22T20:01:43.44
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:380
# ┌ Debug: 	 	 It is b
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:381
# ┌ Debug: 	 	 Size of extra factor: 1; 2020-09-22T20:01:43.441
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:380
# ┌ Debug: 	 	 It is k
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:381
# ┌ Debug: Current degrees of io-equations [(1, [2, 1])]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:107
# ┌ Debug: Orders: [4]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:108
# ┌ Debug: Sizes: [70]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:109
# ┌ Debug: Scores: Tuple{Int64,Rational{Int64},Int64,Int64}[(1, 4//3, 70, 1)]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:120
# ┌ Debug: Prolonging output number 1
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:123
# ┌ Debug: Prolonging
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:127
# ┌ Debug: Eliminating the derivative of A
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:131
# ┌ Debug: 	 Decreasing degree with linear combination 2020-09-22T20:01:43.441
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:297
# ┌ Debug: Eliminating the derivative of J
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:131
# ┌ Debug: 	 Decreasing degree with linear combination 2020-09-22T20:01:43.442
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:297
# ┌ Debug: Elimination of J, 1 left; 2020-09-22T20:01:43.443
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:141
# ┌ Debug: Elimination in states
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:204
# ┌ Debug: 	 Elimination in the equation for A
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:207
# ┌ Debug: 	 Decreasing degree with linear combination 2020-09-22T20:01:43.443
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:297
# ┌ Debug: 	 	 Size of extra factor: 1; 2020-09-22T20:01:43.444
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:380
# ┌ Debug: 	 	 It is alpha
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:381
# ┌ Debug: 	 	 Size of extra factor: 1; 2020-09-22T20:01:43.444
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:380
# ┌ Debug: 	 	 It is q
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:381
# ┌ Debug: 	 	 Size of extra factor: 1; 2020-09-22T20:01:43.444
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:380
# ┌ Debug: 	 	 It is r
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:381
# ┌ Debug: Elimination in y_equations
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:211
# ┌ Debug: 	 Elimination in the prolonged equation
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:220
# ┌ Debug: 	 Decreasing degree with linear combination 2020-09-22T20:01:43.445
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:297
# ┌ Debug: Current degrees of io-equations [(1, [3])]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:107
# ┌ Debug: Orders: [5]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:108
# ┌ Debug: Sizes: [128]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:109
# ┌ Debug: Scores: Tuple{Int64,Rational{Int64},Int64,Int64}[(3, 49//15, 128, 1)]
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:120
# ┌ Debug: Prolonging output number 1
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:123
# ┌ Debug: Prolonging
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:127
# ┌ Debug: Eliminating the derivative of A
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:131
# ┌ Debug: Calculating Sylvester matrix
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:349
# ┌ Debug: Simplifying the matrix 2020-09-22T20:01:43.446
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:353
# ┌ Debug: Removed factors Int64[]
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:356
# ┌ Debug: 	 Matrix size:
# │  [165  42]
# │ [ 12   6]
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:363
# ┌ Debug: 	 Computing determinant 2020-09-22T20:01:43.447
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:364
# ┌ Debug: Discarded: ((1,), (1,)); 2020-09-22T20:01:43.447
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((1,), (2,)); 2020-09-22T20:01:43.447
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((), ()); 2020-09-22T20:01:43.447
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Elimination of A, 0 left; 2020-09-22T20:01:43.45
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:141
# ┌ Debug: Elimination in states
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:204
# ┌ Debug: Elimination in y_equations
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:211
# ┌ Debug: 	 Elimination in the prolonged equation
# └ @ Main /home/gleb/code/EliminationODE/io_equation.jl:220
# ┌ Debug: 	 Decreasing degree with linear combination 2020-09-22T20:01:43.45
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:297
# ┌ Debug: 	 Decreasing degree with linear combination 2020-09-22T20:01:43.45
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:297
# ┌ Debug: Calculating Bezout Matrix 2020-09-22T20:01:43.451
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:345
# ┌ Debug: Simplifying the matrix 2020-09-22T20:01:43.461
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:353
# ┌ Debug: Removed factors [6, 1, 6, 6, 1, 1]
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:356
# ┌ Debug: 	 Matrix size:
# │  [809   773   560]
# │ [773  1976  1035]
# │ [182   417    95]
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:363
# ┌ Debug: 	 Computing determinant 2020-09-22T20:01:43.532
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:364
# ┌ Debug: Discarded: ((1, 2), (1, 2)); 2020-09-22T20:01:43.677
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((1, 2), (1, 3)); 2020-09-22T20:01:43.738
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((1,), (1,)); 2020-09-22T20:01:43.76
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((1, 2), (2, 3)); 2020-09-22T20:01:44.834
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((1,), (2,)); 2020-09-22T20:01:44.845
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((1,), (3,)); 2020-09-22T20:01:45.668
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: Discarded: ((), ()); 2020-09-22T20:01:46.443
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:39
# ┌ Debug: 	 Factoring with Singular a polynomial of size 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:150
# ┌ Debug: 	 Factoring with Singular a polynomial of size 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:150
# ┌ Debug: 	 Factoring with Singular a polynomial of size 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:150
# ┌ Debug: 	 Factoring with Singular a polynomial of size 1
# └ @ Main /home/gleb/code/EliminationODE/util.jl:150
# ┌ Debug: 	 	 Size of extra factor: 1; 2020-09-22T20:01:50.883
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:380
# ┌ Debug: 	 	 It is q
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:381
# ┌ Debug: 	 	 Size of extra factor: 6; 2020-09-22T20:01:50.883
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:380
# ┌ Debug: 	 	 It is alpha*k*y1_1 + alpha*y1_2 + k*g1*y1_1 + k*y1_2 + g1*y1_2 + y1_3
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:381
# ┌ Debug: 	 	 Size of extra factor: 1; 2020-09-22T20:01:50.883
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:380
# ┌ Debug: 	 	 It is b
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:381
# ┌ Debug: 	 	 Size of extra factor: 1; 2020-09-22T20:01:50.883
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:380
# ┌ Debug: 	 	 It is alpha
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:381
# ┌ Debug: 	 	 Size of extra factor: 1; 2020-09-22T20:01:50.884
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:380
# ┌ Debug: 	 	 It is r
# └ @ Main /home/gleb/code/EliminationODE/elimination.jl:381
#  21.852341 seconds (64.62 M allocations: 4.102 GiB, 5.94% gc time)

# %%
length(io_equations[1])
# Out:
# 927131

# %%
@time check_identifiability(
    io_equations[1], 
    [b, k, g1, g2, alpha, r, q];
    method="GroebnerBasis"
)
# Out:
# ┌ Debug: Extracting coefficients
# └ @ Main /home/gleb/code/EliminationODE/util.jl:272
# ┌ Debug: Constructing equations
# └ @ Main /home/gleb/code/EliminationODE/util.jl:227
# ┌ Debug: Pivot polynomial is 9*alpha^3*q*r^4 - 9*alpha^3*q*r^3 - 9*alpha^3*r^4
# └ @ Main /home/gleb/code/EliminationODE/util.jl:232
# ┌ Debug: Computing Groebner basis (1466 equations)
# └ @ Main /home/gleb/code/EliminationODE/util.jl:244
# ┌ Debug: Producing the result
# └ @ Main /home/gleb/code/EliminationODE/util.jl:254
#  26.587970 seconds (131.62 M allocations: 5.331 GiB, 14.88% gc time)
# Dict{Any,Any} with 7 entries:
#   k     => true
#   q     => false
#   r     => false
#   alpha => true
#   b     => true
#   g1    => true
#   g2    => true
